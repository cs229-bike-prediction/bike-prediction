# %%
# %load_ext autoreload

# %%
# %autoreload 2
from bike_prediction import get_coords

# %%
get_coords.load_all_stations()

# %%
get_coords.cache['locs_df']
# Out:
#                                                lats     longs
# River Street , Clerkenwell                51.529163 -0.109971
# Phillimore Gardens, Kensington            51.499607 -0.197574
# Christopher Street, Liverpool Street      51.521284 -0.084606
# St. Chad's Street, King's Cross           51.530059 -0.120974
# Sedding Street, Sloane Square             51.493130 -0.156876
# Broadcasting House, Marylebone            51.518118 -0.144229
# Charlbert Street, St. John's Wood         51.534300 -0.168074
# Lodge Road, St. John's Wood               51.528341 -0.170134
# New Globe Walk, Bankside                  51.507385 -0.096441
# Park Street, Bankside                     51.505974 -0.092754
# Brunswick Square, Bloomsbury              51.523951 -0.122502
# Malet Street, Bloomsbury                  51.521681 -0.130432
# Scala Street, Fitzrovia                   51.519915 -0.136040
# Belgrove Street , King's Cross            51.529944 -0.123617
# Great Russell Street, Bloomsbury          51.517727 -0.127854
# Cartwright Gardens , Bloomsbury           51.526358 -0.125979
# Hatton Wall, Holborn                      51.521661 -0.109006
# Drury Lane, Covent Garden                 51.514771 -0.122220
# Taviton Street, Bloomsbury                51.525051 -0.131161
# Drummond Street , Euston                  51.527736 -0.135273
# Hampstead Road (Cartmel), Euston          51.530078 -0.138846
# Northington Street , Holborn              51.522264 -0.114079
# Red Lion Square, Holborn                  51.519435 -0.119123
# British Museum, Bloomsbury                51.519080 -0.124678
# Doric Way , Somers Town                   51.528834 -0.132250
# Ampton Street , Clerkenwell               51.527281 -0.118295
# Bouverie Street, Temple                   51.513821 -0.107928
# Bolsover Street, Fitzrovia                51.523518 -0.143614
# Hereford Road, Bayswater                  51.513735 -0.193487
# Windsor Terrace, Hoxton                   51.529154 -0.093422
# ...                                             ...       ...
# Hertford Road, De Beauvoir Town           51.537278 -0.079202
# Haggerston Road, Haggerston               51.539329 -0.074285
# Culvert Road, Battersea                   51.471096 -0.157850
# Newton Street, Covent Garden              51.516129 -0.120909
# Manfred Road, East Putney                 51.458165 -0.206002
# Hammersmith Town Hall, Hammersmith        51.492637 -0.234094
# Grenfell Road, Avondale                   51.512901 -0.214763
# The Vale, Chelsea                         51.485122 -0.174972
# Prince of Wales Drive, Battersea Park     51.475154 -0.159170
# Harcourt Terrace, West Brompton           51.487959 -0.187405
# Westbourne Park Road, Portobello          51.517870 -0.201005
# Broadley Terrace, Marylebone              51.524562 -0.165669
# Rossmore Road, Marylebone                 51.525270 -0.163795
# Humbolt Road, Fulham                      51.483217 -0.211861
# Storey's Gate, Westminster                51.500703 -0.129699
# Mile End Park Leisure Centre, Mile End    51.520597 -0.032567
# St. John's Road, Clapham Junction         51.462393 -0.168292
# Ranelagh Gardens, Fulham                  51.467601 -0.206827
# Ram Street, Wandsworth                    51.457529 -0.192166
# Santos Road, Wandsworth                   51.457060 -0.200806
# Clapham Common Northside, Clapham Common  51.461344 -0.159322
# Sandilands Road, Walham Green             51.473611 -0.191803
# Gwendwr Road, West Kensington             51.491026 -0.209121
# Rifle Place, Avondale                     51.509224 -0.216016
# Binfield Road, Stockwell                  51.472510 -0.122832
# Tallis Street, Temple                     51.511891 -0.107349
# Hurlingham Park, Parsons Green            51.470131 -0.204640
# Little Brook Green, Brook Green           51.496664 -0.223868
# Abyssinia Close, Clapham Junction         51.460333 -0.167029
# Limburg Road, Clapham Common              51.461923 -0.165298
#
# [746 rows x 2 columns]

# %%
print get_coords.get_station_distances(1,2)
print get_coords.get_station_distances(1,3)
# Out:
# 0.0924553917148
# 0.0265605821974
